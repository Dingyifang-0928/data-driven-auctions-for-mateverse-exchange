# %%
from SC_VCG_multiprocess_selfish import *
import time

# %%
#实验5 平台虚假报价高10%或者低10%
# 40,6,0.9   40,6,1.1  √
# 80,3,0.9   80,3,1.2   80,3,1.1
# 目标函数使用谎报的价值；agents的payment也用谎报的价值；平台自己的利润使用真实的价值计算=

agent_num,bid_num,cycle = 80,3,20       #agents,bids,cycle
self_bid_range,other_bid_range,platform_bid_range = [0,20],[10,50],[10,50]
platform_selfish = 1.2
#计算数据及保存
compute(agent_num,bid_num,cycle,self_bid_range,other_bid_range,platform_bid_range,platform_selfish)
# Out:
# total time:2165.5291924
# SCE-VCG: t:80,c:0,W(N):2029.85,platform profits:-604.09
# SCE-VCG: t:79,c:0,W(N):2029.85,platform profits:-604.09
# SCE-VCG: t:78,c:0,W(N):2029.85,platform profits:-604.09
# SCE-VCG: t:77,c:0,W(N):2032.42,platform profits:-559.56
# SCE-VCG: t:76,c:0,W(N):2032.21,platform profits:-282.43
# SCE-VCG: t:75,c:0,W(N):2028.97,platform profits:-12.79
# SCE-VCG: t:74,c:0,W(N):1990.42,platform profits:13.96
# SCE-VCG: t:73,c:0,W(N):1986.34,platform profits:17.95
# SCE-VCG: t:72,c:0,W(N):1961.09,platform profits:122.12
# SCE-VCG: t:71,c:0,W(N):1973.89,platform profits:363.75
# SCE-VCG: t:70,c:0,W(N):1948.64,platform profits:143.48
# SCE-VCG: t:69,c:0,W(N):1941.77,platform profits:248.35
# SCE-VCG: t:68,c:0,W(N):1933.3,platform profits:371.04
# SCE-VCG: t:67,c:0,W(N):1921.51,platform profits:484.47
# SCE-VCG: t:66,c:0,W(N):1911.1,platform profits:478.78
# SCE-VCG: t:65,c:0,W(N):1899.72,platform profits:492.38
# SCE-VCG: t:64,c:0,W(N):1886.78,platform profits:486.87
# ...

# %%
0.8
SCE-VCG: t:5,c:0,W(N):162.12,platform profits:-59.56
SCE-VCG: t:4,c:0,W(N):125.26,platform profits:87.88
SCE-VCG: t:3,c:0,W(N):90.37,platform profits:59.73
SCE-VCG: t:2,c:0,W(N):64.51,platform profits:44.35
SCE-VCG: t:1,c:0,W(N):23.93,platform profits:18.15
                    
SCE-VCG: t:5,c:1,W(N):162.25,platform profits:-74.39
SCE-VCG: t:4,c:1,W(N):132.46,platform profits:3.96
SCE-VCG: t:3,c:1,W(N):103.71,platform profits:-5.12
SCE-VCG: t:2,c:1,W(N):46.7,platform profits:34.06
SCE-VCG: t:1,c:1,W(N):28.75,platform profits:27.51
                    
SCE-VCG: t:5,c:2,W(N):153.11,platform profits:-25.55
SCE-VCG: t:4,c:2,W(N):128.28,platform profits:73.77
SCE-VCG: t:3,c:2,W(N):104.9,platform profits:45.77
SCE-VCG: t:2,c:2,W(N):62.13,platform profits:34.47
SCE-VCG: t:1,c:2,W(N):24.33,platform profits:24.11
                    
SCE-VCG: t:5,c:3,W(N):120.82,platform profits:-24.66
SCE-VCG: t:4,c:3,W(N):106.08,platform profits:34.3
SCE-VCG: t:3,c:3,W(N):78.67,platform profits:38.42
SCE-VCG: t:2,c:3,W(N):49.22,platform profits:39.24
SCE-VCG: t:1,c:3,W(N):35.02,platform profits:22.04
SCE-VCG: t:5,c:4,W(N):165.87,platform profits:-40.66
SCE-VCG: t:4,c:4,W(N):122.49,platform profits:84.14
SCE-VCG: t:3,c:4,W(N):110.74,platform profits:71.95
SCE-VCG: t:2,c:4,W(N):67.36,platform profits:44.02
SCE-VCG: t:1,c:4,W(N):43.38,platform profits:32.36

                    
                    
1.2              
SCE-VCG: t:5,c:0,W(N):152.14,platform profits:-41.31
SCE-VCG: t:4,c:0,W(N):129.75,platform profits:89.87
SCE-VCG: t:3,c:0,W(N):104.25,platform profits:67.15
SCE-VCG: t:2,c:0,W(N):75.46,platform profits:57.83
SCE-VCG: t:1,c:0,W(N):40.78,platform profits:34.2
                    
SCE-VCG: t:5,c:1,W(N):163.61,platform profits:-43.86
SCE-VCG: t:4,c:1,W(N):130.31,platform profits:68.07
SCE-VCG: t:3,c:1,W(N):109.55,platform profits:52.77
SCE-VCG: t:2,c:1,W(N):73.74,platform profits:62.6
SCE-VCG: t:1,c:1,W(N):35.81,platform profits:17.67
                    
SCE-VCG: t:5,c:2,W(N):130.73,platform profits:-35.1
SCE-VCG: t:4,c:2,W(N):111.89,platform profits:69.24
SCE-VCG: t:3,c:2,W(N):90.25,platform profits:53.18
SCE-VCG: t:2,c:2,W(N):65.51,platform profits:47.55
SCE-VCG: t:1,c:2,W(N):33.26,platform profits:30.47
                    
SCE-VCG: t:5,c:3,W(N):113.18,platform profits:-53.35
SCE-VCG: t:4,c:3,W(N):111.41,platform profits:-32.95
SCE-VCG: t:3,c:3,W(N):84.09,platform profits:49.55
SCE-VCG: t:2,c:3,W(N):41.58,platform profits:26.2
SCE-VCG: t:1,c:3,W(N):27.32,platform profits:11.03
                    
SCE-VCG: t:5,c:4,W(N):111.25,platform profits:-26.44
SCE-VCG: t:4,c:4,W(N):104.62,platform profits:14.56
SCE-VCG: t:3,c:4,W(N):96.05,platform profits:17.34
SCE-VCG: t:2,c:4,W(N):64.51,platform profits:52.64
SCE-VCG: t:1,c:4,W(N):31.54,platform profits:13.54
